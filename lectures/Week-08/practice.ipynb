# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import sklearn
import warnings
warnings.filterwarnings("ignore")
plt.rc("figure",figsize =(5,5),dpi=100,facecolor="white")

# %%
import warnings 
warnings.simplefilter(action="ignore",category=FutureWarning)

# %%
sns.color_palette()
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %%
sns.palplot(sns.color_palette("Oranges"))

# %%
sns.palplot(sns.color_palette("BrBG",30))

# %%
sns.palplot(sns.color_palette("viridis", 20))

# %%
sns.palplot(sns.color_palette("coolwarm", 20))

# %%
sns.palplot(sns.color_palette('colorblind',20))

# %%
df = pd.read_csv("titanic_dataset.csv").reset_index()
df.head(1)
# Out:
#    index  PassengerId  Survived  Pclass                     Name   Sex   Age  \
# 0      0            1         0       3  Braund, Mr. Owen Harris  male  22.0
#
#    SibSp  Parch     Ticket  Fare Cabin Embarked
# 0      1      0  A/5 21171  7.25   NaN        S

# %%
df.shape
# Out:
# (891, 13)

# %%
df.columns
# Out:
# Index(['index', 'PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age',
#        'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
sns.histplot(df['Pclass'],kde=True)
# Out:
# <AxesSubplot: xlabel='Pclass', ylabel='Count'>

# %%
sns.histplot(df['Parch'],kde=True)
# Out:
# <AxesSubplot: xlabel='Parch', ylabel='Count'>

# %%
df.head(1)
# Out:
#    index  PassengerId  Survived  Pclass                     Name   Sex   Age  \
# 0      0            1         0       3  Braund, Mr. Owen Harris  male  22.0
#
#    SibSp  Parch     Ticket  Fare Cabin Embarked
# 0      1      0  A/5 21171  7.25   NaN        S

# %%
sns.histplot(df['Survived'],kde=False)
# Out:
# <AxesSubplot: xlabel='Survived', ylabel='Count'>

# %%
sns.histplot(df['Survived'],kde=True)
# Out:
# <AxesSubplot: xlabel='Survived', ylabel='Count'>

# %%
sns.histplot(df['Age'], kde=True)
# Out:
# <AxesSubplot: xlabel='Age', ylabel='Count'>

# %%
sns.distplot(df['Age'],hist=False)
# Out:
# <AxesSubplot: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(df['Age'],kde = True)
sns.set(style="ticks")

# %%
df.isnull().sum()
# Out:
# index            0
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.head(1)
# Out:
#    index  PassengerId  Survived  Pclass                     Name   Sex   Age  \
# 0      0            1         0       3  Braund, Mr. Owen Harris  male  22.0
#
#    SibSp  Parch     Ticket  Fare Cabin Embarked
# 0      1      0  A/5 21171  7.25   NaN        S

# %%
sns.relplot(x='Pclass', y='Fare', data=df, kind="lineplot")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# e:\GitHub\AI_Hope_to_Skill\AI-Course-with-Irfan-Malik\Week-08\practice.ipynb Cell 22 in 1
# ----> <a href='vscode-notebook-cell:/e%3A/GitHub/AI_Hope_to_Skill/AI-Course-with-Irfan-Malik/Week-08/practice.ipynb#X26sZmlsZQ%3D%3D?line=0'>1</a> sns.relplot(x='Pclass', y='Fare', data=df, kind="lineplot")
#
# File c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\relational.py:850, in relplot(data, x, y, hue, size, style, units, row, col, col_wrap, row_order, col_order, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, dashes, style_order, legend, kind, height, aspect, facet_kws, **kwargs)
#     848 else:
#     849     err = f"Plot kind {kind} not recognized"
# --> 850     raise ValueError(err)
#     852 # Check for attempt to plot onto specific axes and warn
#     853 if "ax" in kwargs:
# ...

# %%
sns.relplot(x ='Age',y= 'Fare',data= df,kind= 'bar')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# e:\GitHub\AI_Hope_to_Skill\AI-Course-with-Irfan-Malik\Week-08\practice.ipynb Cell 20 in 1
# ----> <a href='vscode-notebook-cell:/e%3A/GitHub/AI_Hope_to_Skill/AI-Course-with-Irfan-Malik/Week-08/practice.ipynb#X24sZmlsZQ%3D%3D?line=0'>1</a> sns.relplot(x ='Age',y= 'Fare',data= df,kind= 'bar')
#
# File c:\Users\lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\relational.py:850, in relplot(data, x, y, hue, size, style, units, row, col, col_wrap, row_order, col_order, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, dashes, style_order, legend, kind, height, aspect, facet_kws, **kwargs)
#     848 else:
#     849     err = f"Plot kind {kind} not recognized"
# --> 850     raise ValueError(err)
#     852 # Check for attempt to plot onto specific axes and warn
#     853 if "ax" in kwargs:
#
# ...
